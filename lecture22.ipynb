# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import sparse
from scipy.sparse import linalg as spla
import spectral

# %% [markdown]
# When an equation has a derivative, we want use the Chebyshev $U$ polynomials as test functions. Let's try taking a derivative using this strategy.

# %%
N = 32
x_basis = spectral.Chebyshev(N)
domain = spectral.Domain([x_basis])
dtype = np.float64
u = spectral.Field(domain, dtype=dtype)
dudx = spectral.Field(domain, dtype=dtype)
x = x_basis.grid()

# %%
u.require_grid_space()
u.data = np.sin(x)

# %%
diag = np.arange(N-1)+1
D = sparse.diags(diag, offsets=1)

# %%
plt.figure()
plt.imshow(np.log(np.abs(D.A)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# /var/folders/8j/kcmh8b0d37lgd3dff3rz5wsc0000gn/T/ipykernel_43489/3237091695.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(D.A)))

# %%
u.require_coeff_space()

# %%
D @ u.data
# Out:
# array([ 8.80101171e-01, -6.62098898e-17, -1.17380124e-01, -1.24949054e-17,
#         2.49757730e-03,  9.49708560e-17, -2.10325614e-05, -1.88110165e-16,
#         9.44865029e-08, -2.03547983e-16, -2.63561918e-10,  1.82573980e-16,
#         5.01076132e-13, -8.76070617e-17, -6.16965750e-16,  9.81307787e-18,
#        -6.33743182e-16,  4.41703658e-16, -2.04621825e-16,  1.78877130e-16,
#        -6.40764422e-16, -2.46435122e-16,  9.54072666e-17, -3.23880600e-16,
#         5.08696224e-16,  2.04695640e-16, -1.19435711e-15,  1.51687242e-16,
#         6.03683770e-16, -9.82561448e-16,  1.72084569e-15,  0.00000000e+00])

# %%
diag0 = np.ones(N)/2
diag0[0] = 1
diag2 = -np.ones(N-2)/2
C = sparse.diags((diag0, diag2), offsets=(0, 2))

# %%
plt.figure()
plt.imshow(np.log(np.abs(C.A)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# /var/folders/8j/kcmh8b0d37lgd3dff3rz5wsc0000gn/T/ipykernel_43489/4149016518.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(C.A)))

# %%
dudx.require_coeff_space()
dudx.data = spla.spsolve(C, D@u.data)
# Out:
# /opt/miniconda3/envs/dedalus_new/lib/python3.8/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:144: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',

# %%
dudx.require_grid_space()
plt.figure()
plt.plot(x, dudx.data)
plt.plot(x, np.cos(x))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now back to Viscous Burgers' equation.

# %%
N = 128
x_basis = spectral.Chebyshev(N)
domain = spectral.Domain([x_basis])
dtype = np.float64
u = spectral.Field(domain, dtype=dtype)
ux = spectral.Field(domain, dtype=dtype)
ux_RHS = spectral.Field(domain, dtype=dtype)
x = x_basis.grid()

# %%
nu = 1e-2
dt = 1e-2
t_end = 10
om = 2*np.pi
num_steps = int(t_end/dt)

# %%
diag = np.arange(N-1)+1
D = sparse.diags(diag, offsets=1)

diag0 = np.ones(N)/2
diag0[0] = 1
diag2 = -np.ones(N-2)/2
C = sparse.diags((diag0, diag2), offsets=(0,2))

# %%
# M matrix
M = sparse.csr_matrix((2*N+2, 2*N+2))
M[N:2*N, :N] = C

# L matrix
Z = np.zeros((N,N))

L = sparse.bmat([[D, -C],
                 [Z, -nu*D]])

BC_rows = np.zeros((2, 2*N))
i = np.arange(N)
BC_rows[0, :N] = (-1)**i
BC_rows[1, :N] = (+1)**i

corner = np.zeros((2, 2))

cols = np.zeros((2*N, 2))
cols[  N-1, 0] = 1
cols[2*N-1, 1] = 1

L = sparse.bmat([[L, cols],
                 [BC_rows, corner]])

LHS = M/dt + L

F = np.zeros(2*N+2)
X = np.zeros(2*N+2)
t = 0

# %%
plt.figure()
plt.imshow(np.log(np.abs(LHS.A)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# /var/folders/8j/kcmh8b0d37lgd3dff3rz5wsc0000gn/T/ipykernel_43489/3767648227.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.abs(LHS.A)))

# %% [markdown]
# Take one timestep:

# %%
u.require_coeff_space()
ux.require_coeff_space()
u.require_grid_space(scales=3/2)
ux.require_grid_space(scales=3/2)
ux_RHS.require_grid_space(scales=3/2)
ux_RHS.data = -u.data * ux.data
ux_RHS.require_coeff_space()
ux_RHS.data = C @ ux_RHS.data
u.require_coeff_space()
ux_RHS.data += C @ u.data
F[N:2*N] = ux_RHS.data
F[2*N] = (1+np.sin(om*t))/2
X = spla.spsolve(LHS, F)
u.data = X[:N]
ux.data = X[N:2*N]
t += dt

# %%
plt.figure()
u.require_grid_space()
plt.plot(x, u.data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now let's take multiple timesteps:

# %%
fig = plt.figure()
u.require_grid_space()
p, = plt.plot(x, u.data)
fig.canvas.draw()
plt.ylim([-0.05,1.05])

for i in range(num_steps//5):
    for j in range(5):
        # take a timestep
        
        
        t += dt
    
    u.require_grid_space()
    p.set_ydata(u.data.real)
    fig.canvas.draw()

# %% [markdown]
# We can write a problem class for Burgers' equation.

# %%
class BurgersEquationChebyshevSparse:
    
    def __init__(self, domain, u, ux, nu):
        self.u = u
        self.ux = ux
        self.domain = domain
        self.dtype = dtype = u.dtype
        self.u_RHS = spectral.Field(domain, dtype=dtype)
        self.ux_RHS = spectral.Field(domain, dtype=dtype)
        self.nu = nu
        
        self.problem = spectral.InitialValueProblem(domain, [u, ux], [self.u_RHS, self.ux_RHS], num_BCs=2, dtype=dtype)
        
        p = self.problem.pencils[0]
        
        # M matrix
        M = sparse.csr_matrix((2*N+2, 2*N+2))
        M[N:2*N, :N] = C

        # L matrix
        Z = np.zeros((N,N))

        L = sparse.bmat([[D, -C],
                         [Z, -nu*D]])

        BC_rows = np.zeros((2, 2*N))
        i = np.arange(N)
        BC_rows[0, :N] = (-1)**i
        BC_rows[1, :N] = (+1)**i

        corner = np.zeros((2, 2))

        cols = np.zeros((2*N, 2))
        cols[  N-1, 0] = 1
        cols[2*N-1, 1] = 1

        L = sparse.bmat([[L, cols],
                         [BC_rows, corner]])

        p.M = M
        p.L = L
        p.L.eliminate_zeros()
        p.M.eliminate_zeros()
        
        self.t = 0
        
    def evolve(self, timestepper, dt, BC_func, num_steps):
        ts = timestepper(self.problem)
        u = self.u
        ux = self.ux
        ux_RHS = self.ux_RHS

        for i in range(num_steps):
            u.require_coeff_space()
            ux.require_coeff_space()
            ux_RHS.require_coeff_space()
            u.require_grid_space(scales=3/2)
            ux.require_grid_space(scales=3/2)
            ux_RHS.require_grid_space(scales=3/2)
            ux_RHS.data = -u.data * ux.data
            ux_RHS.require_coeff_space()
            ux_RHS.data = C @ ux_RHS.data
            ts.step(dt, BC_func(self.t))
            self.t += dt

# %%
N = 128
x_basis = spectral.Chebyshev(N)
domain = spectral.Domain([x_basis])
dtype = np.float64
u = spectral.Field(domain, dtype=dtype)
ux = spectral.Field(domain, dtype=dtype)
BC_func = lambda t: [0.5*(1+np.sin(om*t)), 0]

burgers = BurgersEquationChebyshevSparse(domain, u, ux, nu)
# Out:
# /opt/miniconda3/envs/dedalus_new/lib/python3.8/site-packages/scipy/sparse/_index.py:116: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %%
fig = plt.figure()
u.require_grid_space()
p, = plt.plot(x, u.data)
fig.canvas.draw()
plt.ylim([-0.05,1.05])

for i in range(num_steps//5):
    burgers.evolve(spectral.SBDF2, dt, BC_func, 5)
    
    u.require_grid_space()
    p.set_ydata(u.data.real)
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /opt/miniconda3/envs/dedalus_new/lib/python3.8/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:318: SparseEfficiencyWarning: splu requires CSC matrix format
#   warn('splu requires CSC matrix format', SparseEfficiencyWarning)
